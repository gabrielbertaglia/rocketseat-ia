# %%
import pandas as pd

# %% [markdown]
# ## Criar DataFrames com base nos Datasets

# %%
# Carregar DataFrame de Clientes (Customers)
df_customers = pd.read_csv('./datasets/churn_customers.csv')

# %%
# Mostrar 5 primeiros registros do DataFrame
df_customers.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No
# 3  7795-CFOCW    Male              0      No         No
# 4  9237-HQITU  Female              0      No         No

# %%
# Mostrar 5 últimos registros

df_customers.tail(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents
# 7038  6840-RESVB    Male              0     Yes        Yes
# 7039  2234-XADUH  Female              0     Yes        Yes
# 7040  4801-JZAZL  Female              0     Yes        Yes
# 7041  8361-LTMKD    Male              1     Yes         No
# 7042  3186-AJIEK    Male              0      No         No

# %%
# Mostrar estrutura / schema do DataFrame
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
# Carregar DataFrame de Serviços (Services)
df_services = pd.read_csv('./datasets/churn_services.csv')

# %%
# Mostrar 5 primeiros registros do DataFrame
df_services.head(5)
# Out:
#    customerID PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0  7590-VHVEG           No  No phone service             DSL             No
# 1  5575-GNVDE          Yes                No             DSL            Yes
# 2  3668-QPYBK          Yes                No             DSL            Yes
# 3  7795-CFOCW           No  No phone service             DSL            Yes
# 4  9237-HQITU          Yes                No     Fiber optic             No
#
#   OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies
# 0          Yes               No          No          No              No
# 1           No              Yes          No          No              No
# 2          Yes               No          No          No              No
# 3           No              Yes         Yes          No              No
# 4           No               No          No          No              No

# %%
# Mostrar 5 últimos registros
df_services.tail(5)
# Out:
#       customerID PhoneService     MultipleLines InternetService  \
# 7038  6840-RESVB          Yes               Yes             DSL
# 7039  2234-XADUH          Yes               Yes     Fiber optic
# 7040  4801-JZAZL           No  No phone service             DSL
# 7041  8361-LTMKD          Yes               Yes     Fiber optic
# 7042  3186-AJIEK          Yes                No     Fiber optic
#
#      OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 7038            Yes           No              Yes         Yes         Yes
# 7039             No          Yes              Yes          No         Yes
# 7040            Yes           No               No          No          No
# 7041             No           No               No          No          No
# 7042            Yes           No              Yes         Yes         Yes
#
#      StreamingMovies
# 7038             Yes
# 7039             Yes
# 7040              No
# 7041              No
# 7042             Yes

# %%
# Mostrar estrutura / schema do DataFrame
df_services.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   PhoneService      7043 non-null   object
#  2   MultipleLines     7043 non-null   object
#  3   InternetService   7043 non-null   object
#  4   OnlineSecurity    7043 non-null   object
#  5   OnlineBackup      7043 non-null   object
#  6   DeviceProtection  7043 non-null   object
#  7   TechSupport       7043 non-null   object
#  8   StreamingTV       7043 non-null   object
#  9   StreamingMovies   7043 non-null   object
# dtypes: object(10)
# memory usage: 550.4+ KB

# %%
# Carregar DataFrame de Contratos (Contracts)
df_contracts = pd.read_csv('./datasets/churn_contracts.csv')

# %%
# Mostrar 5 primeiros registros do DataFrame
df_contracts.head(5)
# Out:
#    customerID  tenure        Contract PaperlessBilling  \
# 0  7590-VHVEG       1  Month-to-month              Yes
# 1  5575-GNVDE      34        One year               No
# 2  3668-QPYBK       2  Month-to-month              Yes
# 3  7795-CFOCW      45        One year               No
# 4  9237-HQITU       2  Month-to-month              Yes
#
#                PaymentMethod     MonthlyCharges TotalCharges Churn
# 0           Electronic check 29.850000000000001        29.85    No
# 1               Mailed check 56.950000000000003       1889.5    No
# 2               Mailed check 53.850000000000001       108.15   Yes
# 3  Bank transfer (automatic) 42.299999999999997      1840.75    No
# 4           Electronic check 70.700000000000003       151.65   Yes

# %%
# Mostrar 5 últimos registros
df_contracts.tail(5)
# Out:
#       customerID  tenure        Contract PaperlessBilling  \
# 7038  6840-RESVB      24        One year              Yes
# 7039  2234-XADUH      72        One year              Yes
# 7040  4801-JZAZL      11  Month-to-month              Yes
# 7041  8361-LTMKD       4  Month-to-month              Yes
# 7042  3186-AJIEK      66        Two year              Yes
#
#                   PaymentMethod      MonthlyCharges TotalCharges Churn
# 7038               Mailed check  84.799999999999997       1990.5    No
# 7039    Credit card (automatic) 103.200000000000003       7362.9    No
# 7040           Electronic check  29.600000000000001       346.45    No
# 7041               Mailed check  74.400000000000006        306.6   Yes
# 7042  Bank transfer (automatic) 105.650000000000006       6844.5    No

# %%
# Mostrar estrutura / schema do DataFrame
df_contracts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   tenure            7043 non-null   int64
#  2   Contract          7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7043 non-null   object
#  7   Churn             7043 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 440.3+ KB

# %% [markdown]
# ## Transformação de Dados

# %%
# Transformar caluna TotalCharges de String para Float - Abordagem 3 (to_numeric com coerce)
df_contracts.TotalCharges = pd.to_numeric(df_contracts.TotalCharges, errors='coerce')

# %%
# Mostrar estrutura / schema do DataFrame
df_contracts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   tenure            7043 non-null   int64
#  2   Contract          7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7032 non-null   float64
#  7   Churn             7043 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 440.3+ KB

# %% [markdown]
# Após a transformação da coluna TotalCharges do DataFrame Contracts, a coluna passou a ter 11 valores ausentes (missing values)

# %% [markdown]
# ## Renomear Colunas

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
# Renomear coluna no DataFrame, usando rename e dicionário
df_customers.rename(columns={'SeniorCitizen': 'Above65yo'})
# Out:
#       customerID  gender  Above65yo Partner Dependents
# 0     7590-VHVEG  Female          0     Yes         No
# 1     5575-GNVDE    Male          0      No         No
# 2     3668-QPYBK    Male          0      No         No
# 3     7795-CFOCW    Male          0      No         No
# 4     9237-HQITU  Female          0      No         No
# ...          ...     ...        ...     ...        ...
# 7038  6840-RESVB    Male          0     Yes        Yes
# 7039  2234-XADUH  Female          0     Yes        Yes
# 7040  4801-JZAZL  Female          0     Yes        Yes
# 7041  8361-LTMKD    Male          1     Yes         No
# 7042  3186-AJIEK    Male          0      No         No
#
# [7043 rows x 5 columns]

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
# Criar um DataFrame novo com base nas colunas renomeadas
df_customers_renamed = df_customers.rename(columns={'SeniorCitizen': 'Above65yo'})

# %%
# Mostrar estrutura do Dataframe novo
df_customers_renamed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7043 non-null   object
#  1   gender      7043 non-null   object
#  2   Above65yo   7043 non-null   int64
#  3   Partner     7043 non-null   object
#  4   Dependents  7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
# Aplicar o resultado do rename no próprio Dataframe
df_customers.rename(columns={'SeniorCitizen': 'Above65yo'}, inplace=True)

# %%
# Visualizar estrutura
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7043 non-null   object
#  1   gender      7043 non-null   object
#  2   Above65yo   7043 non-null   int64
#  3   Partner     7043 non-null   object
#  4   Dependents  7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
# Rename usando Lista - Modificar todos os nomes de colunas
df_customers.columns = ['IDCliente', 'genero', 'Mais65Anos', 'TemParceiro', 'TemDependentes']

# %%
# Mostrar estrutura
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   IDCliente       7043 non-null   object
#  1   genero          7043 non-null   object
#  2   Mais65Anos      7043 non-null   int64
#  3   TemParceiro     7043 non-null   object
#  4   TemDependentes  7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %% [markdown]
# ## Unificar Dataframes de Customers, Services e Contracts

# %%
# Contrar quantidade de registros por Dataframe
len(df_customers)
# Out:
# 7043

# %%
len(df_services)
# Out:
# 7043

# %%
len(df_contracts)
# Out:
# 7043

# %%
# Renomear colunas
df_services.rename(columns={'customerID': 'IDCliente'}, inplace=True)

# %%
df_services.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   PhoneService      7043 non-null   object
#  2   MultipleLines     7043 non-null   object
#  3   InternetService   7043 non-null   object
#  4   OnlineSecurity    7043 non-null   object
#  5   OnlineBackup      7043 non-null   object
#  6   DeviceProtection  7043 non-null   object
#  7   TechSupport       7043 non-null   object
#  8   StreamingTV       7043 non-null   object
#  9   StreamingMovies   7043 non-null   object
# dtypes: object(10)
# memory usage: 550.4+ KB

# %%
# Unificar Dataframe de Customers com Services, criando um terceiro DataFrame
df_temp = df_customers.merge(df_services, on=['IDCliente'])

# %%
# Mostrar estrutura dataframe temp
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   genero            7043 non-null   object
#  2   Mais65Anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   object
#  4   TemDependentes    7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
# dtypes: int64(1), object(13)
# memory usage: 770.5+ KB

# %%
df_churn_temp = df_temp.merge(df_contracts, left_on=['IDCliente'], right_on=['customerID'])

# %%
df_churn_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   genero            7043 non-null   object
#  2   Mais65Anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   object
#  4   TemDependentes    7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  customerID        7043 non-null   object
#  15  tenure            7043 non-null   int64
# ...

# %%
# Unificar os três dataframes ao mesmo tempo, com colunas com nomes diferentes
df_churn = df_customers.merge(df_services, on=['IDCliente']).merge(df_contracts, left_on=['IDCliente'], right_on=['customerID'])

# %%
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   genero            7043 non-null   object
#  2   Mais65Anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   object
#  4   TemDependentes    7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  customerID        7043 non-null   object
#  15  tenure            7043 non-null   int64
# ...

# %%
# Removendo coluna de um DataFrame
df_churn.drop(['customerID'], axis=1, inplace=True)

# %% [markdown]
# ## Detecção de Valores ausentes

# %%
# Detectar valores ausentes em todas as colunas de um DataFrame
df_churn.isna().sum()
# Out:
# IDCliente            0
# genero               0
# Mais65Anos           0
# TemParceiro          0
# TemDependentes       0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# tenure               0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
# Detectar valores ausentes em coluna
df_churn.TotalCharges.isna().sum()
# Out:
# np.int64(11)

# %%
# Quantas linhas tem pelo menos 1 coluna com valor ausente
df_churn[df_churn.isna().any(axis=1)]
# Out:
#        IDCliente  genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 488   4472-LVYGI  Female           0         Yes            Yes           No
# 753   3115-CZMZD    Male           0          No            Yes          Yes
# 936   5709-LVOEQ  Female           0         Yes            Yes          Yes
# 1082  4367-NUYAO    Male           0         Yes            Yes          Yes
# 1340  1371-DWPAZ  Female           0         Yes            Yes           No
# 3331  7644-OMVMY    Male           0         Yes            Yes          Yes
# 3826  3213-VVOLG    Male           0         Yes            Yes          Yes
# 4380  2520-SGTTA  Female           0         Yes            Yes          Yes
# 5218  2923-ARZLG    Male           0         Yes            Yes          Yes
# 6670  4075-WKNIU  Female           0         Yes            Yes          Yes
# 6754  2775-SEFEE    Male           0          No            Yes          Yes
#
# ...

# %%
# Quantas colunas tem pelo menos 1 valor ausente
df_churn.isna().any(axis=0).sum()
# Out:
# np.int64(1)

# %% [markdown]
# ## Remover valores ausentes

# %%
# Remover de forma direta e especifica a coluna que possui valores ausentes
df_churn.drop(columns=['TotalCharges'], axis=1)
# Out:
#        IDCliente  genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %%
# Remover colunas com valores ausentes sem ser especifico
df_churn.dropna(axis=1)
# Out:
#        IDCliente  genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %%
# Remover colunas onde todos os valores são ausentes
df_churn.dropna(axis=1, how='all')
# Out:
#        IDCliente  genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %%
# Remover linhas com valores ausentes
df_churn.dropna()
# Out:
#        IDCliente  genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %%
# Remover linhas com todos os valores ausentes
df_churn.dropna(how='all')
# Out:
#        IDCliente  genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %% [markdown]
# ## Imputação de Valores Ausentes

# %%
# Preencher todos os valores ausentes com 0
df_churn.fillna(0)
# Out:
#        IDCliente  genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %%
# Preencher valores padrão conforme a coluna
df_churn.fillna(value={'TotalCharges': 0})
# Out:
#        IDCliente  genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %%
# Preencher todos os valores ausentes de uma coluna com a média
media_TotalCharges = df_churn.TotalCharges.mean()

# %%
media_TotalCharges
# Out:
# np.float64(2283.3004408418656)

# %%
df_churn.fillna(value={'TotalCharges': media_TotalCharges})
# Out:
#        IDCliente  genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %% [markdown]
# ## Análise Univariada

# %% [markdown]
# - A faixa etária do cliente tem uma forte associação com o churn
# - Um cliente com menos de 6 meses de contrato é mais propenso ao churn
# - Cliente com contrato mensal é mais propenso ao churn

# %%
# Contrar clientes usando a variável churn como referência
df_churn.Churn.value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
# Como identificar valores possível (únicos) em uma viável do DataFrame
df_churn.Churn.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# Como é a distribuição de Clientes (%) que abandonaram ou continuam ativos
df_churn.Churn.value_counts(normalize=True)
# Out:
# Churn
# No    0.734630129206304
# Yes   0.265369870793696
# Name: proportion, dtype: float64

# %%
# Plot distribuição Churn (Quantidade)
ax = df_churn.Churn.value_counts().plot.bar()

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '5174'), Text(0, 0, '1869')]

# %%
# Plot distribuição Churn (Percentual)
ax = df_churn.Churn.value_counts(normalize=True).plot.bar()

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '0.73463'), Text(0, 0, '0.26537')]

# %%
# Quais são os tipos de contrato
df_churn.Contract.unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
# Plot distribuição Contract (Quantidade)
ax = df_churn.Contract.value_counts().plot.bar()

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '3875'), Text(0, 0, '1695'), Text(0, 0, '1473')]

# %%
# Plot distribuição Contract (Percentual)
ax = df_churn.Contract.value_counts(normalize=True).plot.bar()

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '0.550192'), Text(0, 0, '0.240664'), Text(0, 0, '0.209144')]

# %%
# Histograma do Tempo de Contrato
df_churn.tenure.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# - A variável tempo de contrato (tenure) não apresenta visualmente uma distribuição normal.
# - A grande parte dos valores se concentram nos extremos, ou seja, contratos com pooucos meses de ativação e contratos longos, acima aproximadamente dos 65 meses.

# %%
# Histograma do Monthly Charges
df_churn.MonthlyCharges.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Medidas de Posição - Média Tempo de Contrato
df_churn.tenure.mean()
# Out:
# np.float64(32.37114865824223)

# %%
# Medidas de Posição - Mediana Tempo de Contrato
df_churn.tenure.median()
# Out:
# np.float64(29.0)

# %%
# Medidas de Posição - Moda Tempo de Contrato
df_churn.tenure.mode()
# Out:
# 0    1
# Name: tenure, dtype: int64

# %%
# Medidas de Dispersão - Desvio Padrão Tempo de Contrato
df_churn.tenure.std()
# Out:
# np.float64(24.55948102309446)

# %%
# Medidas de Dispersão - Coeficiente de Variação
df_churn.tenure.std() / df_churn.tenure.mean() * 100
# Out:
# np.float64(75.86842617906674)

# %%
# Quantos cliente possuem 1  mês de contrato - Filtro
len(df_churn[(df_churn.tenure == 1)])
# Out:
# 613

# %%
# Quanto os clientes de 1 mês de contrato representam %
len(df_churn[(df_churn.tenure == 1)]) / len(df_churn) * 100
# Out:
# 8.70367741019452

# %%
# Quantos clientes possuem 1 e 6 meses de contrato
len(df_churn[(df_churn.tenure >= 1) & (df_churn.tenure <= 6)])
# Out:
# 1470

# %%
# Apresentar a quantidade de clientes por tempo de contrato - Agrupando com sumarização
df_churn.groupby(['tenure'])['tenure'].count().sort_values(ascending=False)
# Out:
# tenure
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: tenure, Length: 73, dtype: int64

# %%
# Apresentar a quantidade de clientes por tempo de contrato - Agrupando com sumarização - Em um plot
df_churn.groupby(['tenure'])['tenure'].count().sort_values().plot.barh(figsize=(20, 20))
# Out:
# <Axes: ylabel='tenure'>

# %% [markdown]
# ## Aálise Bivariada

# %%
# Hipotese: Clientes com Contrato do Tipo Mensal são mais propensos ao Churn
# Contruir Tabela de Contingência entre Tipo de Contrato e Churn - Quantidade
pd.crosstab(df_churn.Churn, df_churn.Contract, margins=True, margins_name='Total')
# Out:
# Contract  Month-to-month  One year  Two year  Total
# Churn
# No                  2220      1307      1647   5174
# Yes                 1655       166        48   1869
# Total               3875      1473      1695   7043

# %%
# Contruir Tabela de Contingência entre Tipo de Contrato e Churn - Proporção
pd.crosstab(df_churn.Churn, df_churn.Contract, normalize='index', margins=True, margins_name='Total')
# Out:
# Contract    Month-to-month          One year          Two year
# Churn
# No       0.429068419018168 0.252609199845381 0.318322381136452
# Yes      0.885500267522739 0.088817549491707 0.025682182985554
# Total    0.550191679681954 0.209143830753940 0.240664489564106

# %% [markdown]
# - Conciderando o publico total, os clientes de contrato mensal representam 55%, porém, se considerermos apenas os clientes que abandonaram o serviço, 88% tinham contrato mensal, dessa forma, podemos afiurmar que há uma correlação entre o tipo de contrato mensal e o abandono

# %%
# Avaliar a correlação entre duas variáveis categóricas (qualitativas)

# Executar um teste de hipótese chamado Chi-Square ou Qui-Quadrado de Pearson
# Num teste de hipotese, duas hipóteses são formuladas:
# Hipótese nula (H0): as duas variáveis são independentes
# Hipotese Complementar (H1): as duas variáveis não são indepedentes

# O teste serve para confirmar ou recusar a hipótese nula (H0)
# Quando a probabilidade de observarmos H0 é inferior a 0.05 (p-value), recusamos a hipótese nula e seguimos com a complementar.

# %%
# Gerar um DF da Crosstab (sem totais)
df_crosstab_churn_contract = pd.crosstab(df_churn.Churn, df_churn.Contract)

# %%
# Calcular os Scores e P-Values
from scipy.stats import chi2_contingency

# %%
# Tupla = Lista imutável
chi_scores_churn_contract = chi2_contingency(df_crosstab_churn_contract)

# %%
chi_scores_churn_contract
# Out:
# Chi2ContingencyResult(statistic=np.float64(1184.5965720837926), pvalue=np.float64(5.863038300673391e-258), dof=2, expected_freq=array([[2846.69175067, 1082.11018032, 1245.198069  ],
#        [1028.30824933,  390.88981968,  449.801931  ]]))

# %%
scores_churn_contract = pd.Series(chi_scores_churn_contract[0])

# %%
pvalues_churn_contract = pd.Series(chi_scores_churn_contract[1])

# %%
# Apresentar numeros com decimais sem a notação científica
pd.set_option('display.float_format', lambda x: '%.15f' % x)

# %%
# Criar DataFrame com os resultados
df_chi_scores_churn_contract = pd.DataFrame({'Qui2': scores_churn_contract, 'p-value': pvalues_churn_contract})

# %%
# Analisar Scores e P-Values
df_chi_scores_churn_contract
# Out:
#                   Qui2           p-value
# 0 1184.596572083792580 0.000000000000000

# %% [markdown]
# Conforme Teste Estatístico (Chi-Squire), o P-value <= 0.05, desta forma rejeitamos a hipótese nula, ou seja, as variáveis são indepedentes. Pelo Qui2 alto, podemos afirmar que há uma forte correlação

# %%
# Avaliar a correlação entre uma variável qualitativa e quantitativa
# Usar o mesmo teste de Chi-Square, mas transformar a variável quantitativa em qualitativa
# Hipótese: Cliente com menos de 6 meses de contrato é mais propenso ao Chrun

# Criar uma coluna nova no DataFrame com base numa condição de outra Coluna
# Coluna = 'TempoMenor6Meses'

import numpy as np

# %%
# Criar coluna nova
df_churn['TempoMenor6Meses'] = np.where(df_churn.tenure<6, 'Yes', 'No')

# %%
# Checar o DataFrame

df_churn.head(5)
# Out:
#     IDCliente  genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 0  7590-VHVEG  Female           0         Yes             No           No
# 1  5575-GNVDE    Male           0          No             No          Yes
# 2  3668-QPYBK    Male           0          No             No          Yes
# 3  7795-CFOCW    Male           0          No             No           No
# 4  9237-HQITU  Female           0          No             No          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0  No phone service             DSL             No          Yes  ...
# 1                No             DSL            Yes           No  ...
# 2                No             DSL            Yes          Yes  ...
# 3  No phone service             DSL            Yes           No  ...
# 4                No     Fiber optic             No           No  ...
#
#   StreamingTV StreamingMovies tenure        Contract  PaperlessBilling  \
# ...

# %%
# Gerar um DF da Crosstab (sem totais)
df_crosstab_churn_tenure = pd.crosstab(df_churn.Churn, df_churn.TempoMenor6Meses)

# %%
# Calcular os cors
chi_scores_churn_tenure = chi2_contingency(df_crosstab_churn_tenure)

# %%
scores_churn_tenure = pd.Series(chi_scores_churn_tenure[0])
pvalues_churn_tenure = pd.Series(chi_scores_churn_tenure[1])

# %%
# Criar DataFrame com os resultados
df_chi_scores_churn_tenure = pd.DataFrame({'Qui2': scores_churn_tenure, 'p-value': pvalues_churn_tenure})

# %%
# Analisar os resultados
df_chi_scores_churn_tenure
# Out:
#                  Qui2           p-value
# 0 669.721615828710242 0.000000000000000

# %% [markdown]
# Como o P-Value <= 0.05, rejeitamos a H0, ou seja, as variáveis não são independentes. E vale mencionar que com base no Qui2 resultante das 2 análises, a correlação entre Churn e Tempo de Contrato < 6 meses é menor do que a correlação entre Churn e Tipo de Contrato

# %%
# Correlação entre 2 variáveis numériacas
# Tenure com TotalCharges
# A intuição é que quanto mais tempo de contrato maior o valor pago.

# Correlação entre 2 variáveis numéricas usando Pearson
df_churn.tenure.corr(df_churn.TotalCharges)
# Out:
# np.float64(0.825880460933202)

# %%
# Correlação entre 2 variáveis numéricas usando Spearman
df_churn.tenure.corr(df_churn.TotalCharges, method='spearman')
# Out:
# np.float64(0.8891770805365491)

# %% [markdown]
# Há uma forte correlção entre Tenure entre TotalCharges, usando métodos estatísticos de correlação.

# %%
# Apresentar Plot Scatter entre Tenure e TotalCharges
# Gráfico de Dispersão
df_churn.plot.scatter(x='tenure', y='TotalCharges')
# Out:
# <Axes: xlabel='tenure', ylabel='TotalCharges'>

# %% [markdown]
# - Desafio1: Validar a primeira hipótese de que a faixa etária do cliente tem uma forte associação com o Churn
# - Desafio2: Validar com Teste de Hipótese se Contrato Mensal está mais propenso ao Churn.

# %%
df_crosstab_churn_above65yo = pd.crosstab(df_churn.Churn, df_churn.Mais65Anos)
chi_scores_churn_above65yo = chi2_contingency(df_crosstab_churn_above65yo)
scores_churn_above65yo = pd.Series(chi_scores_churn_above65yo[0])
pvalues_churn_above65yo = pd.Series(chi_scores_churn_above65yo[1])
df_chi_scores_churn_above65yo = pd.DataFrame({'Qui2': scores_churn_above65yo, 'p-value': pvalues_churn_above65yo})
df_chi_scores_churn_contract
# Out:
#                   Qui2           p-value
# 0 1184.596572083792580 0.000000000000000

# %%
# Desafio 2:
df_crosstab_churn_monthlycharges = pd.crosstab(df_churn.Churn, df_churn.MonthlyCharges)
chi_scores_churn_monthlycharges = chi2_contingency(df_crosstab_churn_monthlycharges)
scores_churn_monthlycharges = pd.Series(chi_scores_churn_monthlycharges[0])
pvalues_churn_monthlycharges = pd.Series(chi_scores_churn_monthlycharges[1])
df_chi_scores_churn_monthlycharges = pd.DataFrame({'Qui2': scores_churn_monthlycharges, 'p-value': pvalues_churn_monthlycharges})
df_chi_scores_churn_monthlycharges
# Out:
#                   Qui2           p-value
# 0 2123.609129997958007 0.000000000000000

# %% [markdown]
# ## Detecção de Outliers (Valores Atípicos)

# %%
# Remover linhas com valores nulos
df_churn.dropna(axis=0, inplace=True)

# %%
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7032 non-null   object
#  1   genero            7032 non-null   object
#  2   Mais65Anos        7032 non-null   int64
#  3   TemParceiro       7032 non-null   object
#  4   TemDependentes    7032 non-null   object
#  5   PhoneService      7032 non-null   object
#  6   MultipleLines     7032 non-null   object
#  7   InternetService   7032 non-null   object
#  8   OnlineSecurity    7032 non-null   object
#  9   OnlineBackup      7032 non-null   object
#  10  DeviceProtection  7032 non-null   object
#  11  TechSupport       7032 non-null   object
#  12  StreamingTV       7032 non-null   object
#  13  StreamingMovies   7032 non-null   object
#  14  tenure            7032 non-null   int64
#  15  Contract          7032 non-null   object
# ...

# %%
# Box Plot Geral
df_churn['TotalCharges'].plot.box()
# Out:
# <Axes: >

# %%
# Box Plot agrupado por Contract
df_churn.plot.box(column='TotalCharges', by='Contract')
# Out:
# TotalCharges    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
# Criar um Dataframe somente com clientes do tipo Month to Month (Contrato mensal)
df_churn_month = df_churn[df_churn.Contract=='Month-to-month']

# %%
df_churn_month
# Out:
#        IDCliente  genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 2     3668-QPYBK    Male           0          No             No          Yes
# 4     9237-HQITU  Female           0          No             No          Yes
# 5     9305-CDSKC  Female           0          No             No          Yes
# 6     1452-KIOVK    Male           0          No            Yes          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7033  9767-FFLEM    Male           0          No             No          Yes
# 7034  0639-TSIQW  Female           0          No             No          Yes
# 7035  8456-QDAVC    Male           0          No             No          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
#
# ...

# %%
# Histrograma - Checar visualmente se os dados seguem uma distribuição normal
df_churn_month.TotalCharges.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Método de Tukey - IQR (Distribuição não normal)
# IQR - Range InterQuartil

# IQR = Q3 - Q1
q1_TotalCharges_month = df_churn_month.TotalCharges.quantile(0.25)
q3_TotalCharges_month = df_churn_month.TotalCharges.quantile(0.75)

iqr_TotalCharges_month = q3_TotalCharges_month - q1_TotalCharges_month
iqr_TotalCharges_month
# Out:
# np.float64(1906.4)

# %%
# Limites Inferior e Superior
limInf_TotalCharges_month = q1_TotalCharges_month - (iqr_TotalCharges_month * 1.5)
limSup_TotalCharges_month = q3_TotalCharges_month + (iqr_TotalCharges_month * 1.5)
limInf_TotalCharges_month, limSup_TotalCharges_month
# Out:
# (np.float64(-2699.5000000000005), np.float64(4926.1))

# %%
df_churn_month[(df_churn_month.TotalCharges < limInf_TotalCharges_month) | (df_churn_month.TotalCharges > limSup_TotalCharges_month)]
# Out:
#        IDCliente  genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 13    0280-XJGEX    Male           0          No             No          Yes
# 61    1215-FIGMP    Male           0          No             No          Yes
# 93    6067-NGCEU  Female           0          No             No          Yes
# 110   0486-HECZI    Male           0         Yes             No          Yes
# 197   6168-YBYNP    Male           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 6897  2363-BJLSL    Male           0          No             No          Yes
# 6952  6394-MFYNG  Female           0          No             No          Yes
# 6965  7789-CRUVC  Female           1         Yes             No          Yes
# 7023  1035-IPQPU  Female           1         Yes             No          Yes
# 7034  0639-TSIQW  Female           0          No             No          Yes
#
# ...

# %%
# ZScore - Usado para a distribuição normal
# Indica quantos desvios padrões um ponto específico de dados está distante da média
# zscore = (x - media) / desvio padrao

from scipy.stats import zscore

# %%
z = np.abs(zscore(df_churn_month.TotalCharges))
z
# Out:
# 0      0.830035854105835
# 2      0.781512944511796
# 4      0.754555772515107
# 5      0.340066014124648
# 6      0.359519077072167
#               ...
# 7033   0.778346771186232
# 7034   3.418910216654943
# 7035   0.077987048610201
# 7040   0.633837218378213
# 7041   0.658532466747594
# Name: TotalCharges, Length: 3875, dtype: float64

# %%
df_churn_month[z > 3.0]
# Out:
#        IDCliente  genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 93    6067-NGCEU  Female           0          No             No          Yes
# 197   6168-YBYNP    Male           0          No             No          Yes
# 339   1343-EHPYB    Male           0         Yes             No          Yes
# 402   0979-PHULV    Male           0         Yes            Yes          Yes
# 445   7752-XUSCI  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 6565  1548-FEHVL    Male           0         Yes             No          Yes
# 6587  7426-GSWPO    Male           1          No             No          Yes
# 6713  4989-LIXVT    Male           1          No             No          Yes
# 7023  1035-IPQPU  Female           1         Yes             No          Yes
# 7034  0639-TSIQW  Female           0          No             No          Yes
#
# ...

# %% [markdown]
# ## Automatizando EDA

# %%
# SweetViz - Abrir no Jupyter Notebook
import sweetviz as sv
from sweetviz.sv_public import analyze
sv_churn_report = analyze(df_churn, target_feat='Churn')
# Out:
# Feature: tenure                              |██████▉   | [ 70%]   08:40 -> (03:47 left)
# Feature: tenure                              |██████▉   | [ 70%]   00:10 -> (00:01 left)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[222], line 4
#       2 import sweetviz as sv
#       3 from sweetviz.sv_public import analyze
# ----> 4 sv_churn_report = analyze(df_churn, target_feat='Churn')
#
# File c:\Users\cursi\.virtualenvs\eda-fHynLqQL\Lib\site-packages\sweetviz\sv_public.py:12, in analyze(source, target_feat, feat_cfg, pairwise_analysis)
#       8 def analyze(source: Union[pd.DataFrame, Tuple[pd.DataFrame, str]],
#       9             target_feat: str = None,
#      10             feat_cfg: FeatureConfig = None,
#      11             pairwise_analysis: str = 'auto'):
# ---> 12     report = sweetviz.DataframeReport(source, target_feat, None,
# ...
